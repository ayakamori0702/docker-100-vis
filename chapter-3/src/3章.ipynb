# %%
import os 
project = '100knock-process-visualization'
chapter = 3
os.chdir(f'/opt/{project}/chapter-{chapter}')

# %% [markdown]
# # ３章 時系列データの加工・可視化１０本ノック

# %% [markdown]
# # 今回扱うデータ
# * person_count_out_0001_○○.csv
# 「大手町・丸の内・有楽町エリアにおける人流オープンデータ
# 対象エリアを通行した人数を1秒でカウントしたデータ

# %% [markdown]
# ## ノック４１：時系列データを読み込んでみよう

# %%
from glob import glob
files = glob('data/person_count_1sec/out_0001/*.csv')
files.sort()
files[:5]
# Out:
# ['data/person_count_1sec/out_0001/person_count_out_0001_2021011509.csv',
#  'data/person_count_1sec/out_0001/person_count_out_0001_2021011510.csv',
#  'data/person_count_1sec/out_0001/person_count_out_0001_2021011511.csv',
#  'data/person_count_1sec/out_0001/person_count_out_0001_2021011512.csv',
#  'data/person_count_1sec/out_0001/person_count_out_0001_2021011513.csv']

# %% [markdown]
# *globモジュールでは、引数に指定されたパターンにマッチするファイルパス名を取得できます
# *特定のディレクトリに存在するファイルに処理を加えたい場合などに、使用します。

# %%
# 一つ目のファイルの確認
import pandas as pd
data = pd.read_csv(files[0])
display(data.head(5))
print(data.dtypes)
# Out:
#    id  place             receive_time  sensor_num  in1  out1  state1  in2  \
# 0   0      1  2021-01-15 09:00:00.144           2  508    73       0   73
# 1   1      1  2021-01-15 09:00:01.146           2  508    73       0   73
# 2   2      1  2021-01-15 09:00:02.161           2  508    73       0   73
# 3   3      1  2021-01-15 09:00:03.176           2  508    73       0   73
# 4   4      1  2021-01-15 09:00:04.192           2  508    73       0   73
#
#    out2  state2
# 0   508       0
# 1   508       0
# 2   508       0
# 3   508       0
# 4   508       0
# id               int64
# place            int64
# receive_time    object
# sensor_num       int64
# in1              int64
# out1             int64
# state1           int64
# in2              int64
# out2             int64
# state2           int64
# dtype: object

# %%
# 全てのファイルの中身を結合。そのときに「receive_time」は、「object」から「datatime」に変換。
data = []
for f in files:
  tmp = pd.read_csv(f, parse_dates=["receive_time"])
  data.append(tmp)
data = pd.concat(data,ignore_index=True)
display(data.head())
len(data)
# Out:
#    id  place            receive_time  sensor_num  in1  out1  state1  in2  \
# 0   0      1 2021-01-15 09:00:00.144           2  508    73       0   73
# 1   1      1 2021-01-15 09:00:01.146           2  508    73       0   73
# 2   2      1 2021-01-15 09:00:02.161           2  508    73       0   73
# 3   3      1 2021-01-15 09:00:03.176           2  508    73       0   73
# 4   4      1 2021-01-15 09:00:04.192           2  508    73       0   73
#
#    out2  state2
# 0   508       0
# 1   508       0
# 2   508       0
# 3   508       0
# 4   508       0
# 2346162

# %% [markdown]
# ## ノック４２：日付の範囲を確認しよう

# %%
min_receive_time = data['receive_time'].min()
max_receive_time = data['receive_time'].max()
print(min_receive_time)
print(max_receive_time)
# Out:
# 2021-01-15 09:00:00.144000
# 2021-02-14 17:59:59.956000

# %%
print(data['receive_time'].max()-data['receive_time'].min())
# Out:
# 30 days 08:59:59.812000

# %% [markdown]
# ## ノック４３：日毎のデータ件数を確認しよう

# %%
# 日単位でのデータ件数 新カラム[receive_date]を用意して、dt.dateで日にちでまとめる
data['receive_date'] = data['receive_time'].dt.date
data.head()
# Out:
#    id  place            receive_time  sensor_num  in1  out1  state1  in2  \
# 0   0      1 2021-01-15 09:00:00.144           2  508    73       0   73
# 1   1      1 2021-01-15 09:00:01.146           2  508    73       0   73
# 2   2      1 2021-01-15 09:00:02.161           2  508    73       0   73
# 3   3      1 2021-01-15 09:00:03.176           2  508    73       0   73
# 4   4      1 2021-01-15 09:00:04.192           2  508    73       0   73
#
#    out2  state2 receive_date
# 0   508       0   2021-01-15
# 1   508       0   2021-01-15
# 2   508       0   2021-01-15
# 3   508       0   2021-01-15
# 4   508       0   2021-01-15

# %%
daily_count = data[['receive_date','id']].groupby('receive_date', as_index=False).count()
daily_count.head()
# Out:
#   receive_date     id
# 0   2021-01-15  50166
# 1   2021-01-16  75699
# 2   2021-01-17  73198
# 3   2021-01-18  78365
# 4   2021-01-19  78348

# %%
# 30日分のデータ数を可視化
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 5))
plt.xticks(rotation=90)  # x軸の回転
sns.barplot(x=daily_count['receive_date'], y=daily_count["id"])
# Out:
# Duplicate key in file PosixPath('/opt/conda/lib/python3.9/site-packages/matplotlib/mpl-data/matplotlibrc'), line 767 ('font.family : IPAexGothic')
# <AxesSubplot:xlabel='receive_date', ylabel='id'>

# %% [markdown]
# ## ノック４４：日付から曜日を算出しよう

# %%
data['dayofweek'] = data['receive_time'].dt.dayofweek  # 曜日を数字で取得
data['day_name'] = data['receive_time'].dt.day_name()  # 曜日を英語名で取得
data.head()
# Out:
#    id  place            receive_time  sensor_num  in1  out1  state1  in2  \
# 0   0      1 2021-01-15 09:00:00.144           2  508    73       0   73
# 1   1      1 2021-01-15 09:00:01.146           2  508    73       0   73
# 2   2      1 2021-01-15 09:00:02.161           2  508    73       0   73
# 3   3      1 2021-01-15 09:00:03.176           2  508    73       0   73
# 4   4      1 2021-01-15 09:00:04.192           2  508    73       0   73
#
#    out2  state2 receive_date  dayofweek day_name
# 0   508       0   2021-01-15          4   Friday
# 1   508       0   2021-01-15          4   Friday
# 2   508       0   2021-01-15          4   Friday
# 3   508       0   2021-01-15          4   Friday
# 4   508       0   2021-01-15          4   Friday

# %%
#重複の削除
data[['receive_date','dayofweek','day_name']].drop_duplicates(subset='receive_date').head(10)
# Out:
#        receive_date  dayofweek   day_name
# 0        2021-01-15          4     Friday
# 50166    2021-01-16          5   Saturday
# 125865   2021-01-17          6     Sunday
# 199063   2021-01-18          0     Monday
# 277428   2021-01-19          1    Tuesday
# 355776   2021-01-20          2  Wednesday
# 434668   2021-01-21          3   Thursday
# 513010   2021-01-22          4     Friday
# 593585   2021-01-23          5   Saturday
# 668686   2021-01-24          6     Sunday

# %% [markdown]
# データ件数の少ない23,24日は土曜、日曜だったことがわかる

# %% [markdown]
# ## ノック４５：特定範囲のデータに絞り込もう

# %% [markdown]
# 1月20日〜1月22日までの範囲に絞り込み

# %%
import datetime as dt
data_extract = data.loc[(data['receive_time']>=dt.datetime(2021,1,20))&
                        (data['receive_time']<dt.datetime(2021,1,23))].copy()
display(data_extract.head())
display(data_extract.tail())
# Out:
#         id  place            receive_time  sensor_num    in1   out1  state1  \
# 355776   0      1 2021-01-20 00:00:40.839           2  12109  11302       0
# 355777   1      1 2021-01-20 00:00:41.854           2  12109  11302       0
# 355778   2      1 2021-01-20 00:00:56.055           2  12109  11302       0
# 355779   3      1 2021-01-20 00:00:57.071           2  12109  11302       0
# 355780   4      1 2021-01-20 00:00:58.086           2  12109  11302       0
#
#           in2   out2  state2 receive_date  dayofweek   day_name
# 355776  11318  12080       0   2021-01-20          2  Wednesday
# 355777  11318  12080       0   2021-01-20          2  Wednesday
# 355778  11318  12080       0   2021-01-20          2  Wednesday
# 355779  11318  12080       0   2021-01-20          2  Wednesday
# 355780  11318  12080       0   2021-01-20          2  Wednesday
#           id  place            receive_time  sensor_num    in1   out1  state1  \
# 593580  2620      1 2021-01-22 23:58:32.865           2  21150  19675       0
# 593581  2621      1 2021-01-22 23:58:33.881           2  21150  19675       0
# 593582  2622      1 2021-01-22 23:58:34.896           2  21150  19675       0
# 593583  2623      1 2021-01-22 23:58:35.912           2  21150  19675       0
# 593584  2624      1 2021-01-22 23:58:36.927           2  21150  19675       0
#
#           in2   out2  state2 receive_date  dayofweek day_name
# 593580  19701  21107       0   2021-01-22          4   Friday
# 593581  19701  21107       0   2021-01-22          4   Friday
# 593582  19701  21107       0   2021-01-22          4   Friday
# 593583  19701  21107       0   2021-01-22          4   Friday
# 593584  19701  21107       0   2021-01-22          4   Friday

# %% [markdown]
# ## ノック４６：秒単位のデータを作成しよう

# %%
# ミリ秒を秒単位に変換
data_extract['receive_time_sec'] = data_extract['receive_time'].dt.round('S')  # roundは四捨五入
data_extract.head()
# Out:
#         id  place            receive_time  sensor_num    in1   out1  state1  \
# 355776   0      1 2021-01-20 00:00:40.839           2  12109  11302       0
# 355777   1      1 2021-01-20 00:00:41.854           2  12109  11302       0
# 355778   2      1 2021-01-20 00:00:56.055           2  12109  11302       0
# 355779   3      1 2021-01-20 00:00:57.071           2  12109  11302       0
# 355780   4      1 2021-01-20 00:00:58.086           2  12109  11302       0
#
#           in2   out2  state2 receive_date  dayofweek   day_name  \
# 355776  11318  12080       0   2021-01-20          2  Wednesday
# 355777  11318  12080       0   2021-01-20          2  Wednesday
# 355778  11318  12080       0   2021-01-20          2  Wednesday
# 355779  11318  12080       0   2021-01-20          2  Wednesday
# 355780  11318  12080       0   2021-01-20          2  Wednesday
#
#           receive_time_sec
# 355776 2021-01-20 00:00:41
# 355777 2021-01-20 00:00:42
# 355778 2021-01-20 00:00:56
# 355779 2021-01-20 00:00:57
# 355780 2021-01-20 00:00:58

# %%
#重複がないか確認
print(len(data_extract))
print(len(data_extract['receive_time_sec'].unique()))
# Out:
# 237809
# 237807

# %%
#重複箇所の確認
data_extract[data_extract['receive_time_sec'].duplicated(keep=False)].head()  # 重複箇所全てを見たい場合は、keep=Falseにすることを忘れない
# Out:
#          id  place            receive_time  sensor_num    in1   out1  state1  \
# 578874  887      1 2021-01-22 19:15:06.530           2  20968  18976       1
# 578875  888      1 2021-01-22 19:15:07.409           2  20968  18976       1
# 578876  889      1 2021-01-22 19:15:07.546           2  20968  18976       1
# 578877  890      1 2021-01-22 19:15:08.424           2  20968  18976       1
#
#           in2   out2  state2 receive_date  dayofweek day_name  \
# 578874  19002  20925       1   2021-01-22          4   Friday
# 578875  19002  20925       1   2021-01-22          4   Friday
# 578876  19002  20925       1   2021-01-22          4   Friday
# 578877  19002  20925       1   2021-01-22          4   Friday
#
#           receive_time_sec
# 578874 2021-01-22 19:15:07
# 578875 2021-01-22 19:15:07
# 578876 2021-01-22 19:15:08
# 578877 2021-01-22 19:15:08

# %%
data_extract['receive_time_sec'] = data_extract['receive_time'].dt.floor('S')  # floorは切り捨て
display(data_extract.head())
#重複がないか確認
print(len(data_extract))
print(len(data_extract['receive_time_sec'].unique()))
# Out:
#         id  place            receive_time  sensor_num    in1   out1  state1  \
# 355776   0      1 2021-01-20 00:00:40.839           2  12109  11302       0
# 355777   1      1 2021-01-20 00:00:41.854           2  12109  11302       0
# 355778   2      1 2021-01-20 00:00:56.055           2  12109  11302       0
# 355779   3      1 2021-01-20 00:00:57.071           2  12109  11302       0
# 355780   4      1 2021-01-20 00:00:58.086           2  12109  11302       0
#
#           in2   out2  state2 receive_date  dayofweek   day_name  \
# 355776  11318  12080       0   2021-01-20          2  Wednesday
# 355777  11318  12080       0   2021-01-20          2  Wednesday
# 355778  11318  12080       0   2021-01-20          2  Wednesday
# 355779  11318  12080       0   2021-01-20          2  Wednesday
# 355780  11318  12080       0   2021-01-20          2  Wednesday
#
#           receive_time_sec
# 355776 2021-01-20 00:00:40
# 355777 2021-01-20 00:00:41
# 355778 2021-01-20 00:00:56
# 355779 2021-01-20 00:00:57
# 355780 2021-01-20 00:00:58
# 237809
# 237808

# %%
#重複箇所の確認
data_extract[data_extract['receive_time_sec'].duplicated(keep=False)].head()
# Out:
#          id  place            receive_time  sensor_num    in1   out1  state1  \
# 578875  888      1 2021-01-22 19:15:07.409           2  20968  18976       1
# 578876  889      1 2021-01-22 19:15:07.546           2  20968  18976       1
#
#           in2   out2  state2 receive_date  dayofweek day_name  \
# 578875  19002  20925       1   2021-01-22          4   Friday
# 578876  19002  20925       1   2021-01-22          4   Friday
#
#           receive_time_sec
# 578875 2021-01-22 19:15:07
# 578876 2021-01-22 19:15:07

# %%
data_extract = data_extract.drop_duplicates(subset=['receive_time_sec'])
min_receive_time = data_extract['receive_time_sec'].min()
max_receive_time = data_extract['receive_time_sec'].max()
print(len(data_extract))
print(f'{min_receive_time}から{max_receive_time}')
# Out:
# 237808
# 2021-01-20 00:00:40から2021-01-22 23:58:36

# %% [markdown]
# ## ノック４７：秒単位のデータを整形しよう

# %% [markdown]
# 行番号355777と355778の間には１秒以上空いていまっている。
# →機械学習では不都合になってしまうケースもある。
#
# 今回は1秒間隔に日付データをあらかじめ作成し、そこに今回のデータを結合してみる。
# 日付データの作成は、.date_range を使用する。
# [参考URL](https://pandas.pydata.org/docs/user_guide/timeseries.html#timeseries-offset-aliases)

# %%
# お試し
print(pd.date_range('2021-01-15', '2021-01-16', freq='S'))  # Sは１秒ごと
# Out:
# DatetimeIndex(['2021-01-15 00:00:00', '2021-01-15 00:00:01',
#                '2021-01-15 00:00:02', '2021-01-15 00:00:03',
#                '2021-01-15 00:00:04', '2021-01-15 00:00:05',
#                '2021-01-15 00:00:06', '2021-01-15 00:00:07',
#                '2021-01-15 00:00:08', '2021-01-15 00:00:09',
#                ...
#                '2021-01-15 23:59:51', '2021-01-15 23:59:52',
#                '2021-01-15 23:59:53', '2021-01-15 23:59:54',
#                '2021-01-15 23:59:55', '2021-01-15 23:59:56',
#                '2021-01-15 23:59:57', '2021-01-15 23:59:58',
#                '2021-01-15 23:59:59', '2021-01-16 00:00:00'],
#               dtype='datetime64[ns]', length=86401, freq='S')

# %%
#今回のデータで作成
base_data = pd.DataFrame({'receive_time_sec':pd.date_range(min_receive_time, max_receive_time,freq='S')})
display(base_data.head())
display(base_data.tail())
print(len(base_data))
# Out:
#      receive_time_sec
# 0 2021-01-20 00:00:40
# 1 2021-01-20 00:00:41
# 2 2021-01-20 00:00:42
# 3 2021-01-20 00:00:43
# 4 2021-01-20 00:00:44
#           receive_time_sec
# 259072 2021-01-22 23:58:32
# 259073 2021-01-22 23:58:33
# 259074 2021-01-22 23:58:34
# 259075 2021-01-22 23:58:35
# 259076 2021-01-22 23:58:36
# 259077

# %% [markdown]
# 日付データ件数は、259077件。センサデータ件数は237808件。
# なのでセンサデータには21269件の欠損があることがわかる。

# %%
#日付データと、センサデータの結合
data_base_extract = pd.merge(base_data, data_extract, on='receive_time_sec', how='left')
display(data_base_extract.head())
display(data_base_extract.isna().sum())
# Out:
#      receive_time_sec   id  place            receive_time  sensor_num  \
# 0 2021-01-20 00:00:40  0.0    1.0 2021-01-20 00:00:40.839         2.0
# 1 2021-01-20 00:00:41  1.0    1.0 2021-01-20 00:00:41.854         2.0
# 2 2021-01-20 00:00:42  NaN    NaN                     NaT         NaN
# 3 2021-01-20 00:00:43  NaN    NaN                     NaT         NaN
# 4 2021-01-20 00:00:44  NaN    NaN                     NaT         NaN
#
#        in1     out1  state1      in2     out2  state2 receive_date  dayofweek  \
# 0  12109.0  11302.0     0.0  11318.0  12080.0     0.0   2021-01-20        2.0
# 1  12109.0  11302.0     0.0  11318.0  12080.0     0.0   2021-01-20        2.0
# 2      NaN      NaN     NaN      NaN      NaN     NaN          NaN        NaN
# 3      NaN      NaN     NaN      NaN      NaN     NaN          NaN        NaN
# 4      NaN      NaN     NaN      NaN      NaN     NaN          NaN        NaN
#
#     day_name
# 0  Wednesday
# 1  Wednesday
# 2        NaN
# 3        NaN
# 4        NaN
# receive_time_sec        0
# id                  21269
# place               21269
# receive_time        21269
# sensor_num          21269
# in1                 21269
# out1                21269
# state1              21269
# in2                 21269
# out2                21269
# state2              21269
# receive_date        21269
# dayofweek           21269
# day_name            21269
# dtype: int64

# %% [markdown]
# ## ノック４８：秒間の欠損データを処理しよう

# %% [markdown]
# 欠損データを保管する方法
# ・０やデータの平均値で埋める　→　売上データなどで多い
# ・１つ前か後ろの値で埋める
# ・線形補完等、前後関係から計算した結果で埋める → 加速度データ、温度データ　（interpolate()使用）

# %%
data_base_extract.sort_values('receive_time_sec',inplace=True)  # 欠損値を埋める前には必ずソートする！
data_base_extract = data_base_extract.fillna(method='ffill')
data_base_extract.head()
# Out:
#      receive_time_sec   id  place            receive_time  sensor_num  \
# 0 2021-01-20 00:00:40  0.0    1.0 2021-01-20 00:00:40.839         2.0
# 1 2021-01-20 00:00:41  1.0    1.0 2021-01-20 00:00:41.854         2.0
# 2 2021-01-20 00:00:42  1.0    1.0 2021-01-20 00:00:41.854         2.0
# 3 2021-01-20 00:00:43  1.0    1.0 2021-01-20 00:00:41.854         2.0
# 4 2021-01-20 00:00:44  1.0    1.0 2021-01-20 00:00:41.854         2.0
#
#        in1     out1  state1      in2     out2  state2 receive_date  dayofweek  \
# 0  12109.0  11302.0     0.0  11318.0  12080.0     0.0   2021-01-20        2.0
# 1  12109.0  11302.0     0.0  11318.0  12080.0     0.0   2021-01-20        2.0
# 2  12109.0  11302.0     0.0  11318.0  12080.0     0.0   2021-01-20        2.0
# 3  12109.0  11302.0     0.0  11318.0  12080.0     0.0   2021-01-20        2.0
# 4  12109.0  11302.0     0.0  11318.0  12080.0     0.0   2021-01-20        2.0
#
#     day_name
# 0  Wednesday
# 1  Wednesday
# 2  Wednesday
# 3  Wednesday
# 4  Wednesday

# %% [markdown]
# ## ノック４９：通った人数を可視化しよう

# %% [markdown]
# 使用データ　in1, out1(累計なので、1秒前のデータとの引き算が必要)
# in1:特定の線に対して、左から入って出ていった人数
# out1:　　　　　　　　 右から入って出ていった人数

# %%
# 必要なカラムだけ取り出し
data_analytics = data_base_extract[['receive_time_sec','in1','out1']].copy()
data_analytics.head()
# Out:
#      receive_time_sec      in1     out1
# 0 2021-01-20 00:00:40  12109.0  11302.0
# 1 2021-01-20 00:00:41  12109.0  11302.0
# 2 2021-01-20 00:00:42  12109.0  11302.0
# 3 2021-01-20 00:00:43  12109.0  11302.0
# 4 2021-01-20 00:00:44  12109.0  11302.0

# %%
#1秒前のデータ作成
data_before_1sec = data_analytics.shift(1)
data_before_1sec.head()
# Out:
#      receive_time_sec      in1     out1
# 0                 NaT      NaN      NaN
# 1 2021-01-20 00:00:40  12109.0  11302.0
# 2 2021-01-20 00:00:41  12109.0  11302.0
# 3 2021-01-20 00:00:42  12109.0  11302.0
# 4 2021-01-20 00:00:43  12109.0  11302.0

# %%
#カラムの設定
data_before_1sec.columns = ['receive_time_sec_b1sec','in1_b1sec','out1_b1sec']
#結合
data_analytics = pd.concat([data_analytics, data_before_1sec],axis=1) # indexをキーに結合
data_analytics.head()
# Out:
#      receive_time_sec      in1     out1 receive_time_sec_b1sec  in1_b1sec  \
# 0 2021-01-20 00:00:40  12109.0  11302.0                    NaT        NaN
# 1 2021-01-20 00:00:41  12109.0  11302.0    2021-01-20 00:00:40    12109.0
# 2 2021-01-20 00:00:42  12109.0  11302.0    2021-01-20 00:00:41    12109.0
# 3 2021-01-20 00:00:43  12109.0  11302.0    2021-01-20 00:00:42    12109.0
# 4 2021-01-20 00:00:44  12109.0  11302.0    2021-01-20 00:00:43    12109.0
#
#    out1_b1sec
# 0         NaN
# 1     11302.0
# 2     11302.0
# 3     11302.0
# 4     11302.0

# %%
# 引き算
data_analytics['in1_calc'] = data_analytics['in1'] - data_analytics['in1_b1sec'] 
data_analytics['out1_calc'] = data_analytics['out1'] - data_analytics['out1_b1sec'] 
data_analytics.head()
# Out:
#      receive_time_sec      in1     out1 receive_time_sec_b1sec  in1_b1sec  \
# 0 2021-01-20 00:00:40  12109.0  11302.0                    NaT        NaN
# 1 2021-01-20 00:00:41  12109.0  11302.0    2021-01-20 00:00:40    12109.0
# 2 2021-01-20 00:00:42  12109.0  11302.0    2021-01-20 00:00:41    12109.0
# 3 2021-01-20 00:00:43  12109.0  11302.0    2021-01-20 00:00:42    12109.0
# 4 2021-01-20 00:00:44  12109.0  11302.0    2021-01-20 00:00:43    12109.0
#
#    out1_b1sec  in1_calc  out1_calc
# 0         NaN       NaN        NaN
# 1     11302.0       0.0        0.0
# 2     11302.0       0.0        0.0
# 3     11302.0       0.0        0.0
# 4     11302.0       0.0        0.0

# %% [markdown]
# ### 時単位での可視化

# %%
# [receive_time_sec]をstrftimeによって文字列型に変換
data_analytics['date_hour'] = data_analytics['receive_time_sec'].dt.strftime('%Y%m%d%H')
data_analytics.head()
# Out:
#      receive_time_sec      in1     out1 receive_time_sec_b1sec  in1_b1sec  \
# 0 2021-01-20 00:00:40  12109.0  11302.0                    NaT        NaN
# 1 2021-01-20 00:00:41  12109.0  11302.0    2021-01-20 00:00:40    12109.0
# 2 2021-01-20 00:00:42  12109.0  11302.0    2021-01-20 00:00:41    12109.0
# 3 2021-01-20 00:00:43  12109.0  11302.0    2021-01-20 00:00:42    12109.0
# 4 2021-01-20 00:00:44  12109.0  11302.0    2021-01-20 00:00:43    12109.0
#
#    out1_b1sec  in1_calc  out1_calc   date_hour
# 0         NaN       NaN        NaN  2021012000
# 1     11302.0       0.0        0.0  2021012000
# 2     11302.0       0.0        0.0  2021012000
# 3     11302.0       0.0        0.0  2021012000
# 4     11302.0       0.0        0.0  2021012000

# %%
# 1時間あたりに変換
viz_data = data_analytics[['date_hour','in1_calc','out1_calc']].groupby('date_hour',as_index=False).sum()
# 可視化用に縦持ち変換
viz_data = pd.melt(viz_data, id_vars='date_hour', value_vars=['in1_calc', 'out1_calc'])
viz_data.head()
# Out:
#     date_hour  variable  value
# 0  2021012000  in1_calc    3.0
# 1  2021012001  in1_calc    1.0
# 2  2021012002  in1_calc    1.0
# 3  2021012003  in1_calc    0.0
# 4  2021012004  in1_calc    1.0

# %%
# 時系列データなので、折れ線グラフ
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.lineplot(x=viz_data['date_hour'], y=viz_data["value"], hue=viz_data['variable'])
# Out:
# <AxesSubplot:xlabel='date_hour', ylabel='value'>

# %% [markdown]
# ## ノック５０：移動平均を計算して可視化しよう

# %%
# データの絞り込み
viz_data = data_analytics[['date_hour','in1_calc','out1_calc']].groupby('date_hour',as_index=False).sum()
viz_data.head(10)
# Out:
#     date_hour  in1_calc  out1_calc
# 0  2021012000       3.0        7.0
# 1  2021012001       1.0        0.0
# 2  2021012002       1.0        0.0
# 3  2021012003       0.0        1.0
# 4  2021012004       1.0        2.0
# 5  2021012005       9.0        3.0
# 6  2021012006      38.0        8.0
# 7  2021012007     182.0       24.0
# 8  2021012008     298.0       49.0
# 9  2021012009     205.0       66.0

# %%
# 今回は3時間移動平均
viz_data_rolling = viz_data[['in1_calc','out1_calc']].rolling(3).mean()
viz_data_rolling.head(10)
# Out:
#      in1_calc  out1_calc
# 0         NaN        NaN
# 1         NaN        NaN
# 2    1.666667   2.333333
# 3    0.666667   0.333333
# 4    0.666667   1.000000
# 5    3.333333   2.000000
# 6   16.000000   4.333333
# 7   76.333333  11.666667
# 8  172.666667  27.000000
# 9  228.333333  46.333333

# %% [markdown]
# rollongメソッド:指定したデータ分スライドさせながら平均を取っていく
# [参考URL](https://www.yutaka-note.com/entry/pandas_rolling)
# index番号0,1がNanなのは、３時間の平均をとるためのデータがないため。

# %%
# 可視化するため縦持ちデータに変換
viz_data_rolling['date_hour'] = viz_data['date_hour']
viz_data_rolling = pd.melt(viz_data_rolling, id_vars='date_hour', value_vars=['in1_calc', 'out1_calc'])
viz_data_rolling.head()
# Out:
#     date_hour  variable     value
# 0  2021012000  in1_calc       NaN
# 1  2021012001  in1_calc       NaN
# 2  2021012002  in1_calc  1.666667
# 3  2021012003  in1_calc  0.666667
# 4  2021012004  in1_calc  0.666667

# %%
# 可視化
plt.figure(figsize=(15, 5))
plt.xticks(rotation=90)
sns.lineplot(x=viz_data_rolling['date_hour'], y=viz_data_rolling["value"], hue=viz_data_rolling['variable'])
# Out:
# <AxesSubplot:xlabel='date_hour', ylabel='value'>

# %% [markdown]
# 平均にすると、動きが緩やか。
